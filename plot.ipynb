# %% [markdown]
# # Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Plot test accuracy

# %% [markdown]
# ## Varying datasets

# %%
SMALL_SIZE = 16
MEDIUM_SIZE = 20
BIGGER_SIZE = 24

acc_dict = {
    'SAS': [60.75, 64.58, 67.54, 68.67], # Resnet50, Cifar100
    'RN10, Cifar10': [59.16, 63.91, 66.61, 66.96],
    'RN10, Cifar100': [59.18, 65.01, 66.62, 67.02],
    'RN10, STL10': [59.49, 63.86, 66.47, 66.83],
    'RN10, IN1K': [58.9, 63.99, 66.31, 66.76],
}

X = np.array([20, 40, 60, 80])
acc_full = 69.13
list_method = ['SAS', 'RN10, Cifar10', 'RN10, Cifar100', 'RN10, STL10', 'RN10, IN1K']
list_color = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown']

# Configure plot
plt.figure(figsize=(6.4,4.8))
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

ax = plt.subplot()

for idx, method in enumerate(list_method):
    list_acc = acc_dict[method]
    plt.plot(X, np.array(list_acc), lw=2, linestyle='-', marker='o', color=list_color[idx], label=method)

plt.axhline(y=acc_full, linestyle='-.', color='black', label='Full data')
plt.ylim(58, 70)
plt.grid()
plt.legend(loc="lower right")
plt.xlabel("Subset size (%)")
plt.ylabel("Top-1 Accuracy (%)")
plt.savefig('figures/effect_of_proxy_model_vary_dataset.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Using pretrained models from Huggingface

# %%
SMALL_SIZE = 16
MEDIUM_SIZE = 20
BIGGER_SIZE = 24

acc_dict = {
    'SAS': [60.75, 64.58, 67.54, 68.67], # Resnet50, Cifar100
    'MAE, IN1K': [59.15, 64.42, 66.27, 66.83],
    'Sup, IN1K': [59.66, 64.56, 66.7, 67.69],
    'DINO, IN1K': [60.61, 64.77, 66.86, 67.24],
    'Sup, IN21K': [59.02, 64.52, 66.57, 67.62]
}

X = np.array([20, 40, 60, 80])
acc_full = 69.13
list_method = ['SAS', 'Sup, IN1K', 'Sup, IN21K', 'MAE, IN1K', 'DINO, IN1K']
list_color = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown']

# Configure plot
plt.figure(figsize=(6.4,4.8))
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

ax = plt.subplot()

for idx, method in enumerate(list_method):
    list_acc = acc_dict[method]
    plt.plot(X, np.array(list_acc), lw=2, linestyle='-', marker='o', color=list_color[idx], label=method)

plt.axhline(y=acc_full, linestyle='-.', color='black', label='Full data')
plt.ylim(58, 70)
plt.grid()
plt.legend(loc="lower right")
plt.xlabel("Subset size (%)")
plt.ylabel("Top-1 Accuracy (%)")
plt.savefig('figures/effect_of_proxy_model_from_pretrain.pdf', bbox_inches='tight')
plt.show()
